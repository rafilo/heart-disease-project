# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn import datasets, linear_model
import seaborn as sns

df = pd.read_csv('aac_intakes_outcomes.csv', header = 0)

df.head(5)
# Out:
#   age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype  \
# 0         10 years           A006100  2007-07-09 00:00:00             NaN
# 1          7 years           A006100  2007-07-09 00:00:00             NaN
# 2          6 years           A006100  2007-07-09 00:00:00             NaN
# 3         10 years           A047759  2004-04-02 00:00:00         Partner
# 4         16 years           A134067  1997-10-16 00:00:00             NaN
#
#       outcome_type sex_upon_outcome  age_upon_outcome_(days)  \
# 0  Return to Owner    Neutered Male                     3650
# 1  Return to Owner    Neutered Male                     2555
# 2  Return to Owner    Neutered Male                     2190
# 3         Transfer    Neutered Male                     3650
# 4  Return to Owner    Neutered Male                     5840
#
#    age_upon_outcome_(years) age_upon_outcome_age_group     outcome_datetime  \
# ...

# %%
df.count()
# Out:
# age_upon_outcome              79672
# animal_id_outcome             79672
# date_of_birth                 79672
# outcome_subtype               36348
# outcome_type                  79662
# sex_upon_outcome              79671
# age_upon_outcome_(days)       79672
# age_upon_outcome_(years)      79672
# age_upon_outcome_age_group    79672
# outcome_datetime              79672
# outcome_month                 79672
# outcome_year                  79672
# outcome_monthyear             79672
# outcome_weekday               79672
# outcome_hour                  79672
# outcome_number                79672
# dob_year                      79672
# dob_month                     79672
# dob_monthyear                 79672
# age_upon_intake               79672
# animal_id_intake              79672
# animal_type                   79672
# breed                         79672
# color                         79672
# found_location                79672
# intake_condition              79672
# ...

# %%
dfrefine = df.drop(columns = ['outcome_datetime','outcome_month','outcome_year','outcome_monthyear','outcome_weekday','outcome_hour','outcome_number','intake_datetime','intake_month','intake_year','intake_monthyear','intake_weekday','intake_hour','intake_number','count','animal_id_outcome'])

# %%
dfrefine.head()
# Out:
#   age_upon_outcome        date_of_birth outcome_subtype     outcome_type  \
# 0         10 years  2007-07-09 00:00:00             NaN  Return to Owner
# 1          7 years  2007-07-09 00:00:00             NaN  Return to Owner
# 2          6 years  2007-07-09 00:00:00             NaN  Return to Owner
# 3         10 years  2004-04-02 00:00:00         Partner         Transfer
# 4         16 years  1997-10-16 00:00:00             NaN  Return to Owner
#
#   sex_upon_outcome  age_upon_outcome_(days)  age_upon_outcome_(years)  \
# 0    Neutered Male                     3650                      10.0
# 1    Neutered Male                     2555                       7.0
# 2    Neutered Male                     2190                       6.0
# 3    Neutered Male                     3650                      10.0
# 4    Neutered Male                     5840                      16.0
#
#   age_upon_outcome_age_group  dob_year  dob_month         ...           \
# ...

# %%
dfrefine.count()
# Out:
# age_upon_outcome              79672
# date_of_birth                 79672
# outcome_subtype               36348
# outcome_type                  79662
# sex_upon_outcome              79671
# age_upon_outcome_(days)       79672
# age_upon_outcome_(years)      79672
# age_upon_outcome_age_group    79672
# dob_year                      79672
# dob_month                     79672
# dob_monthyear                 79672
# age_upon_intake               79672
# animal_id_intake              79672
# animal_type                   79672
# breed                         79672
# color                         79672
# found_location                79672
# intake_condition              79672
# intake_type                   79672
# sex_upon_intake               79671
# age_upon_intake_(days)        79672
# age_upon_intake_(years)       79672
# age_upon_intake_age_group     79672
# time_in_shelter               79672
# time_in_shelter_days          79672
# dtype: int64

# %%
color_list = []
for i in range(len(dfrefine['sex_upon_intake'])):
    color_list.append(dfrefine['sex_upon_intake'][i])

# %%
plt.hist(color_list,edgecolor = 'black')
plt.title('histogram of gender')
plt.xlabel('color')
plt.ylabel('freq')
plt.show()
